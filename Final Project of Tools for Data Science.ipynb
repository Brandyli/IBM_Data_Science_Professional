# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Brandy Li__: My current desired occupation is __Data scientist__ upon graduation

# %% [markdown]
# _I am interested in data science because I am passionate uncovering data-driven insights for leadership decision-making and making the business sustainable_

# %% [markdown]
# ### Test

# %%
a = 'brandy'
b = 'best'
c = (a+ " is the "+b)
c
# Out:
# 'brandy is the best'

# %% [markdown]
# I am the first graduate in my family
# ---
# When I immgrated to the U.S. three years ago, I was lost. But now, I know who I am, and where I should be.
# I am proud of myself to be
# * A New Yorker
# * A Baruch Graduate
# * A Data scientist
# ---
# Now I am glad to announce that I am a MBA ~~candidate~~!
#
# ![image.png](attachment:image.png)
